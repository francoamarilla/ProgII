-- %% [markdown]
-- # [dbo].[DetalleEnvios]

-- %%
USE [db_envios]
GO

-- %%
/****** Object:  Table [dbo].[DetalleEnvios]    Script Date: 26/9/2025 19:02:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetalleEnvios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[id_envio] [int] NOT NULL,
	[id_producto] [int] NOT NULL,
	[cantidad] [int] NOT NULL,
	[comentario] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Envios]

-- %%
/****** Object:  Table [dbo].[Envios]    Script Date: 26/9/2025 19:02:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Envios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [date] NOT NULL,
	[dniCliente] [int] NOT NULL,
	[direccion] [varchar](100) NOT NULL,
	[palabraSecreta] [varchar](100) NOT NULL,
	[estado] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 26/9/2025 19:02:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[id] [int] NOT NULL,
	[nombre] [varchar](255) NOT NULL,
	[precio] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [fk_detalle_envio]

-- %%
ALTER TABLE [dbo].[DetalleEnvios]  WITH CHECK ADD  CONSTRAINT [fk_detalle_envio] FOREIGN KEY([id_envio])
REFERENCES [dbo].[Envios] ([id])
GO
ALTER TABLE [dbo].[DetalleEnvios] CHECK CONSTRAINT [fk_detalle_envio]
GO

-- %% [markdown]
-- # [fk_detalle_productos]

-- %%
ALTER TABLE [dbo].[DetalleEnvios]  WITH CHECK ADD  CONSTRAINT [fk_detalle_productos] FOREIGN KEY([id_producto])
REFERENCES [dbo].[Productos] ([id])
GO
ALTER TABLE [dbo].[DetalleEnvios] CHECK CONSTRAINT [fk_detalle_productos]
GO
